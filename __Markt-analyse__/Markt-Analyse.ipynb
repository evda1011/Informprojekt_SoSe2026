# %% [markdown]
# # **Marktanalyse des Zigarettenkonsums in Deutschland (1965–2025)**
# Die Marktanalyse untersucht die Entwicklung des Zigarettenkonsums in Deutschland zwischen 1965 und 2025.
# Im Fokus stehen Konsum, Preisentwicklung und Tabaksteuer.
#
# ## **Ziel:**
# Ziel der Analyse ist es, Veränderungen des deutschen Zigarettenmarktes zu untersuchen und mögliche Zusammenhänge zwischen Preis, Steuer und Konsum zu analysieren.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from IPython.display import Image, display

# %% [markdown]
# ### **1) Frage (Trend & Faktoren):**
# ### Wie hat sich der Konsum von Zigaretten pro Einwohner zwischen 1965 und 2025 verändert und welche Faktoren könnten die Trendwende erklären?

# %%
from IPython.display import Image, display

display(Image("Grafiken/zigaretten_trend.png"))

# %% [markdown]
# Abbildung1 zeigt die Entwicklung des durchschnittlichen Zigarettenkonsums pro Einwohner zwischen 1965 und 2025
#
# ### **Interpretation:**
#
# Der Konsum erreichte seinen Höchststand in den 1970er-Jahren.
# Seit den 2000er-Jahren ist jedoch ein deutlicher Rückgang erkennbar.
#
# Mögliche Ursachen sind:
# - steigende Preise,
# - staatliche Regulierungen,
# - Gesundheitskampagnen,
# - gesellschaftlicher Wandel.

# %% [markdown]
# ### **Fazit:**
# Der Konsum sank von ca. 2.100 Zigaretten pro Kopf (1970) auf 795 (2025) – ein Rückgang um über 60 %. Hauptfaktoren sind steigende Preise (Steuererhöhungen), Werbe- und Rauchverbote sowie die Verlagerung auf E-Zigaretten.
#
# Der langfristige Rückgang ist eindeutig, aber seit 2023 flacht die Kurve ab – der Konsum stagniert auf historischem Tief.

# %% [markdown]
# ### **2) Frage (Preis- und Steuerentwicklung):**
# ### Wie wirksam ist die Tabaksteuer als Steuerungsinstrument im deutschen Zigarettenmarkt?

# %%
from IPython.display import Image, display

display(Image("Grafiken/Preis_und_Steuern.png"))

# %% [markdown]
# Abbildung 2 zeigt die Entwicklung der Zigarettenpreise, der Tabaksteuer sowie des Steueranteils zwischen 1991 und 2025.
#
# ### **Interpretation:**
# Die Preise für Zigaretten sind langfristig deutlich gestiegen.
# Auch die Tabaksteuer entwickelte sich kontinuierlich nach oben.
#
# Der hohe Steueranteil zeigt den starken Einfluss staatlicher Regulierung auf den Zigarettenmarkt.

# %% [markdown]
# ### **Fazit:**
# Die Korrelation zwischen Preis und Konsum ist mit **r = -0,94** extrem stark – Preiserhöhungen senken den Konsum. Der Steueranteil liegt seit 1990 konstant bei ca. 58–60 %, doch seit 2023 zeigt der Preismechanismus kaum noch Wirkung.
#
# Die Tabaksteuer ist ein sehr wirksames, aber nicht mehr ausreichendes Instrument. Am „harten Kern“ der Raucher versagt der Preiseffekt – ergänzende Maßnahmen (Aromenverbot, Werbeverbote) werden zunehmend entscheidend

# %% [markdown]
# ### **3) Frage:** Besteht ein Zusammenhang zwischen steigenden Preisen und sinkendem Konsum?

# %%
from IPython.display import Image, display

display(Image("Grafiken/Preis_vs_Konsum_Zeitverlauf.png"))

# %% [markdown]
# Abbildung3  vergleicht den Zigarettenpreis mit dem durchschnittlichen Konsum pro Einwohner.

# %%
display(Image("Grafiken/Preis_vs_Konsum_Korrelation.png"))

# %% [markdown]
# Abbildung4 zeigt zusätzlich die Regressionslinie den allgemeinen Zusammenhang der Daten.
#
# ### **Interpretation:**
#
# Die Analyse zeigt eine negative Korrelation zwischen Preis und Konsum.
#
# Mit steigenden Preisen sinkt langfristig der durchschnittliche Zigarettenkonsum.
# Dies deutet auf einen möglichen Einfluss der Preisentwicklung auf das Konsumverhalten hin.

# %% [markdown]
# ### **Fazit:**
# Die Marktanalyse zeigt einen langfristigen Rückgang des Zigarettenkonsums in Deutschland.
# Gleichzeitig steigen Preise und Tabaksteuer kontinuierlich an.
#
# Die Ergebnisse deuten darauf hin, dass wirtschaftliche und politische Faktoren das Konsumverhalten beeinflussen.

# %% [markdown]
# ### **4)Frage(Regulatorische Entwicklung der Tabakprävention):**
# ### Welche gesetzlichen Maßnahmen begleiteten die Entwicklung des Zigarettenkonsums zwischen 2000 und 2023?

# %%
display(Image("Grafiken/tabak_timeline.png"))

# %% [markdown]
# ### **Interpretation:**
# Die gesetzlichen Maßnahmen wurden zwischen 2000 und 2023 kontinuierlich erweitert. Dabei kamen neben Steuererhöhungen zunehmend Werbeverbote, Jugendschutz- und Produktregulierungen hinzu.
#
# ### **Fazit:**
# Die Ergebnisse zeigen eine fortschreitende Verschärfung der Tabakprävention in Deutschland. Die Kombination verschiedener regulatorischer Maßnahmen dürfte zur langfristigen Reduzierung des Zigarettenkonsums beigetragen haben.
